# %% [markdown]
# <a href="https://colab.research.google.com/github/jennynovo-nerd/CISC101-Group--PaperSummarizer/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello")
# Out:
# hello
